# %%
import pandas as pd

# %% [markdown]
# EDA
# ├── Dataset shape
# ├── Data types
# ├── Missing values
# ├── Duplicates
# ├── Target distribution
# ├── Numerical distribution
# ├── Categorical distribution
# └── Outliers
# 👤 Nhóm 1 — Thông tin khách hàng
# | Feature     | Kiểu               | Ý nghĩa                      |
# | ----------- | ------------------ | ---------------------------- |
# | `age`       | Numerical          | Tuổi                         |
# | `job`       | Categorical        | Nghề nghiệp                  |
# | `marital`   | Categorical        | Tình trạng hôn nhân          |
# | `education` | Categorical        | Trình độ học vấn             |
# | `default`   | Categorical/Binary | Có tín dụng bị default không |
# | `balance`   | Numerical          | Số dư trung bình hàng năm    |
# | `housing`   | Categorical/Binary | Có khoản vay nhà không       |
# | `loan`      | Categorical/Binary | Có khoản vay cá nhân không   |
#
# 📞 Nhóm 2 — Thông tin lần liên hệ hiện tại
# | Feature    | Kiểu        | Ý nghĩa             |
# | ---------- | ----------- | ------------------- |
# | `contact`  | Categorical | Phương thức liên hệ |
# | `day`      | Numerical   | Ngày liên hệ        |
# | `month`    | Categorical | Tháng liên hệ       |
# | `duration` | Numerical   | Thời lượng cuộc gọi |
#
# 📊 Nhóm 3 — Lịch sử campaign
# | Feature    | Kiểu        | Ý nghĩa                                |
# | ---------- | ----------- | -------------------------------------- |
# | `campaign` | Numerical   | Số lần liên hệ trong campaign hiện tại |
# | `pdays`    | Numerical   | Số ngày từ lần liên hệ campaign trước  |
# | `previous` | Numerical   | Số lần liên hệ trước campaign hiện tại |
# | `poutcome` | Categorical | Kết quả campaign trước                 |

# %%
DATA_PATH = r'D:\AI_Projects\ML-Lab\data\raw\bank_marketing\bank\bank-full.csv'
data = pd.read_csv(DATA_PATH, sep= ";")
print(data.head())
print(data.shape)
print(data.columns.tolist())
print(data.info())
print(data.isnull().sum())
# Out:
#    age           job  marital  education default  balance housing loan  \
# 0   58    management  married   tertiary      no     2143     yes   no
# 1   44    technician   single  secondary      no       29     yes   no
# 2   33  entrepreneur  married  secondary      no        2     yes  yes
# 3   47   blue-collar  married    unknown      no     1506     yes   no
# 4   33       unknown   single    unknown      no        1      no   no
#
#    contact  day month  duration  campaign  pdays  previous poutcome   y
# 0  unknown    5   may       261         1     -1         0  unknown  no
# 1  unknown    5   may       151         1     -1         0  unknown  no
# 2  unknown    5   may        76         1     -1         0  unknown  no
# 3  unknown    5   may        92         1     -1         0  unknown  no
# 4  unknown    5   may       198         1     -1         0  unknown  no
# (45211, 17)
# ...

# %% [markdown]
# ## 3. Duplicate Analysis

# %%
duplicate_count = data.duplicated().sum()
print(f"Number of duplicates: {duplicate_count}")
# Out:
# Number of duplicates: 0

# %% [markdown]
# ## 4. Target Distribution

# %%
data['y'].value_counts()
# Out:
# y
# no     39922
# yes     5289
# Name: count, dtype: int64
